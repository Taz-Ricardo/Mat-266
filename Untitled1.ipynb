# %%
nieve <- c(23.1, 31.8, 30.4, 39.5, 52.5, 30.5, 12.4, 31.5, 27.6, 32.8, 32.0, 24.0, 24.2, 37.9, 25.1, 35.1, 21.1 )
agua <- c(10.5, 18.2, 16.3, 23.1, 24.9, 14.1, 8.8, 14.9, 16.1 , 16.7, 17.0, 10.5, 12.4, 22.8, 12.9, 17.4, 10.5)
data_2.6 <- data.frame(nieve, agua)
data_2.6
# Out:
#    nieve agua
# 1  23.1  10.5
# 2  31.8  18.2
# 3  30.4  16.3
# 4  39.5  23.1
# 5  52.5  24.9
# 6  30.5  14.1
# 7  12.4   8.8
# 8  31.5  14.9
# 9  27.6  16.1
# 10 32.8  16.7
# 11 32.0  17.0
# 12 24.0  10.5
# 13 24.2  12.4
# 14 37.9  22.8
# 15 25.1  12.9
# 16 35.1  17.4
# 17 21.1  10.5

# %%
regresion_2.7 <- lm(data_2.6$agua ~ data_2.6$nieve)
summary(regresion_2.7)
# Out:
# Call:
# lm(formula = data_2.6$agua ~ data_2.6$nieve)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1793 -1.5149 -0.3624  1.6276  3.1973
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     0.72538    1.54882   0.468    0.646
# data_2.6$nieve  0.49808    0.04952  10.058 4.63e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.743 on 15 degrees of freedom
# Multiple R-squared:  0.8709,	Adjusted R-squared:  0.8623
# F-statistic: 101.2 on 1 and 15 DF,  p-value: 4.632e-08

# %%
plot(data_2.6$nieve, data_2.6$agua, xlab='Concentración de agua en nieve', ylab='Caudal del rio', main='Concentración de agua en nieve vs Caudal del rio', xlim=c(0,60),ylim=c(0,60)) 
abline(regresion_2.7)
# Out:
# Plot with title “Concentración de agua en nieve vs Caudal del rio”

# %%
plot(data_2.6$nieve, data_2.6$agua, xlab='Concentración de agua en nieve', ylab='Caudal del rio', main='Concentración de agua en nieve vs Caudal del rio', xlim=c(0,60),ylim=c(0,60)) 
abline(regresion_2.7.1)
# Out:
# Plot with title “Concentración de agua en nieve vs Caudal del rio”
